# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

from gather_raven_examples import display_raven_recording, write_raven_annotations

import pandas as pd
import numpy as np
from etils import epath
from chirp.inference.search import bootstrap
from scipy.io import wavfile
# Out:
# 2024-06-28 13:46:28.171052: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-28 13:46:28.205161: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-28 13:46:28.205209: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-28 13:46:28.205217: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-28 13:46:28.211278: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
raven = pd.read_csv('./comparison/raven_annotations.csv')

# %%
audio, fp = display_raven_recording(
    raven_annotations=raven,
    ARU_path=epath.Path('./ARU_data_all'),
    labeled_path=epath.Path('./labeled_outputs'),
)
# Out:
# ARU_data_all/2018/BLUE-6-CAPLE_20180606_070000.wav
# Recording: ARU_data_all/2018/BLUE-6-CAPLE_20180606_070000.wav, species: stejay, timestamp: 5.0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
write_raven_annotations(
    audio=audio,
    filepaths=fp,
    type='song',
)

# %%
write_raven_annotations(
    audio=audio,
    filepaths=fp,
    type='call',
)
